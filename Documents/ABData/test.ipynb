# %%
import pandas as pd

# %%
df = pd.read_csv("VentFlowGasMigrationReport.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39638 entries, 0 to 39637
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   01.Report Date                        39638 non-null  object
#  1   02.Licence Number                     39638 non-null  object
#  2   03.Current Licence Status             39638 non-null  object
#  3   04.Surface Location                   39638 non-null  object
#  4   05.Bottom Location                    39627 non-null  object
#  5   06.Original BA Id                     39638 non-null  object
#  6   07.Licensee at Reporting              39638 non-null  object
#  7   08.Type                               39635 non-null  object
#  8   09.Classification                     39635 non-null  object
#  9   10.Flow Substance                     38666 non-null  object
#  10  11.Flow Rate (m3/day)                 22767 non-null  float64
#  11  12.Stabilized Shut In Pressure (kPa)  36040 non-null  float64
#  12  13.Source Depth (mkb)                 16445 non-null  float64
#  13  14.Ground Water Base (mkb)            39533 non-null  float64
#  14  15.Resolution Date                    28210 non-null  object
#  15  16.Reported Resolution                28458 non-null  object
# dtypes: float64(4), object(12)
# memory usage: 4.8+ MB

# %%
import pandas as pd
import numpy as np
import re

def clean_ventflow_types(df: pd.DataFrame) -> pd.DataFrame:
    # --- rename to snake_case
    rename_map = {
        '01.Report Date':'report_date',
        '02.Licence Number':'licence',
        '03.Current Licence Status':'licence_status',
        '04.Surface Location':'surface_location',
        '05.Bottom Location':'bottom_location',
        '06.Original BA Id':'original_ba_id',
        '07.Licensee at Reporting':'licensee_at_reporting',
        '08.Type':'event_type',
        '09.Classification':'classification',
        '10.Flow Substance':'flow_substance',
        '11.Flow Rate (m3/day)':'flow_rate_m3d',
        '12.Stabilized Shut In Pressure (kPa)':'sip_kpa',
        '13.Source Depth (mkb)':'source_depth_mkb',
        '14.Ground Water Base (mkb)':'gw_base_mkb',
        '15.Resolution Date':'resolution_date',
        '16.Reported Resolution':'reported_resolution'
    }
    df = df.rename(columns=rename_map).copy()

    # --- strip whitespace globally
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

    # --- normalize licence (keep raw too)
    df["licence_raw"] = df["licence"]
    df["licence"] = (df["licence"]
        .str.replace(r'^[Ww]\s*', '', regex=True)  # drop leading W
        .str.replace(r'\s+', '', regex=True))      # drop spaces

    # --- parse dates
    for c in ["report_date", "resolution_date"]:
        df[c] = pd.to_datetime(df[c], errors="coerce")

    # --- numeric coercion
    num_cols = ["flow_rate_m3d", "sip_kpa", "source_depth_mkb", "gw_base_mkb"]
    for c in num_cols:
        df[c] = pd.to_numeric(df[c], errors="coerce")

    # --- count zeros in depth fields
    zero_source = (df["source_depth_mkb"] == 0).sum()
    zero_gw = (df["gw_base_mkb"] == 0).sum()
    print(f"Zeros in source_depth_mkb: {zero_source}")
    print(f"Zeros in gw_base_mkb: {zero_gw}")

    # --- normalize classification text and cast categoricals
    df["classification"] = (df["classification"]
        .str.strip()
        .str.replace(r'(?i)^ser.*','Serious', regex=True)
        .str.replace(r'(?i)^non[-\s]?ser.*','Non Serious', regex=True))

    cat_cols = [
        "licence_status","event_type","classification","flow_substance",
        "reported_resolution","licensee_at_reporting","surface_location","bottom_location"
    ]
    for c in cat_cols:
        if c in df.columns:
            df[c] = df[c].astype("category")

    # --- derived fields
    df["delta_gw"] = df["gw_base_mkb"] - df["source_depth_mkb"]    # +ve => source deeper than GW base
    df["duration_days"] = (df["resolution_date"] - df["report_date"]).dt.days
    df["is_serious"] = (df["classification"] == "Serious").astype("Int8")
    df["report_year"] = df["report_date"].dt.year.astype("Int16")

    return df

# Usage:
# df = pd.read_csv("VentFlowGasMigrationReport.csv")
# df_clean = clean_ventflow_types(df)

# %%
df = pd.read_csv("VentFlowGasMigrationReport.csv")   # your original (as you showed)
df_clean = clean_ventflow_types(df)
df_clean.info(memory_usage="deep")
df_clean.head()
# Out:
# /tmp/ipykernel_5996/3096156775.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# /tmp/ipykernel_5996/3096156775.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[c] = pd.to_datetime(df[c], errors="coerce")
# /tmp/ipykernel_5996/3096156775.py:38: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[c] = pd.to_datetime(df[c], errors="coerce")
# Zeros in source_depth_mkb: 9046
# Zeros in gw_base_mkb: 8630
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39638 entries, 0 to 39637
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   report_date            39638 non-null  datetime64[ns]
#  1   licence                39638 non-null  object
#  2   licence_status         39638 non-null  category
#  3   surface_location       39638 non-null  category
#  4   bottom_location        39627 non-null  category
#  5   original_ba_id         39638 non-null  object
#  6   licensee_at_reporting  39638 non-null  category
#  7   event_type             39635 non-null  category
#  8   classification         39635 non-null  category
#  9   flow_substance         38666 non-null  category
#  10  flow_rate_m3d          22767 non-null  float64
#  11  sip_kpa                36040 non-null  float64
#  12  source_depth_mkb       16445 non-null  float64
#  13  gw_base_mkb            39533 non-null  float64
#  14  resolution_date        28210 non-null  datetime64[ns]
#  15  reported_resolution    28458 non-null  category
#  16  licence_raw            39638 non-null  object
#  17  delta_gw               16392 non-null  float64
#  18  duration_days          28210 non-null  float64
#  19  is_serious             39638 non-null  Int8
#  20  report_year            39638 non-null  Int16
# dtypes: Int16(1), Int8(1), category(8), datetime64[ns](2), float64(6), object(3)
# memory usage: 16.7 MB
#   report_date  licence licence_status surface_location bottom_location  \
# 0  1996-01-29  0075880      Cancelled   10-14-062-05W4             NaN
# 1  1997-10-27  0107747      Cancelled   16-23-050-04W5             NaN
# 2  1996-01-25  0123230      Cancelled   07-20-045-07W4             NaN
# 3  1995-11-21  0123683      Cancelled   01-35-041-13W4             NaN
# 4  1996-01-25  0134794      Cancelled   15-22-040-13W4             NaN
#
#   original_ba_id                     licensee_at_reporting event_type  \
# 0           0TC5     Vintage Petroleum Canada, Inc. (0TC5)  Vent Flow
# 1           0MY7  Murphy Canada Exploration Company (0MY7)  Vent Flow
# 2           0BP8               Obsidian Energy Ltd. (0BP8)  Vent Flow
# 3           0R36      Keles Production Company Ltd. (0R36)  Vent Flow
# 4           0R46       Husky Oil Operations Limited (0R46)  Vent Flow
#
#   classification flow_substance  ...  sip_kpa  source_depth_mkb  gw_base_mkb  \
# 0        Serious            Gas  ...      0.0               0.0          0.0
# 1    Non Serious  Not Converted  ...      NaN               0.0          0.0
# 2    Non Serious            Gas  ...      NaN               0.0          0.0
# 3    Non Serious            Gas  ...     60.0               0.0          0.0
# 4    Non Serious            Gas  ...      0.0               0.0          0.0
#
#    resolution_date reported_resolution licence_raw delta_gw  duration_days  \
# 0       1996-01-29            Died Out   W 0075880      0.0            0.0
# 1       1997-10-27    Problem Repaired   W 0107747      0.0            0.0
# 2       1994-12-07    Problem Repaired   W 0123230      0.0         -414.0
# 3       1993-02-10    Problem Repaired   W 0123683      0.0        -1014.0
# 4       1996-01-25            Died Out   W 0134794      0.0            0.0
#
#    is_serious  report_year
# 0           1         1996
# 1           0         1997
# 2           0         1996
# 3           0         1995
# 4           0         1996
#
# [5 rows x 21 columns]

# %%
df[100:130]
# Out:
#                01.Report Date 02.Licence Number 03.Current Licence Status  \
# 100  1998-04-17 12:00:00 a.m.         W 0142197                 Abandoned
# 101  2014-10-24 12:00:00 a.m.         W 0445591                    Issued
# 102  2020-10-28 12:00:00 a.m.         W 0445591                    Issued
# 103  2014-09-12 12:00:00 a.m.         W 0445591                    Issued
# 104  2007-01-15 12:00:00 a.m.         W 0362553                 Abandoned
# 105  2023-08-23 12:00:00 a.m.         W 0414819                Suspension
# 106  2011-08-26 12:00:00 a.m.         W 0422035                 Abandoned
# 107  2000-02-15 12:00:00 a.m.         W 0118245              RecCertified
# 108  2012-09-18 12:00:00 a.m.         W 0338838                Suspension
# 109  2002-11-07 12:00:00 a.m.         W 0090097              RecCertified
# 110  2009-02-04 12:00:00 a.m.         W 0402469                    Issued
# 111  2018-05-31 12:00:00 a.m.         W 0406866                    Issued
# 112  2005-07-29 12:00:00 a.m.         W 0003045              RecCertified
# 113  2008-04-01 12:00:00 a.m.         W 0314450                 Abandoned
# 114  2011-06-24 12:00:00 a.m.         W 0093282                 Abandoned
# 115  2020-08-26 12:00:00 a.m.         W 0093282                 Abandoned
# 116  1999-07-29 12:00:00 a.m.         W 0092985                 Abandoned
# 117  2000-05-05 12:00:00 a.m.         W 0092985                 Abandoned
# 118  2009-04-13 12:00:00 a.m.         W 0409751              RecCertified
# 119  2000-07-27 12:00:00 a.m.         W 0215817                Suspension
# 120  2007-04-11 12:00:00 a.m.         W 0373571                    Issued
# 121  2016-05-25 12:00:00 a.m.         W 0344304                Suspension
# 122  2017-02-27 12:00:00 a.m.         W 0480982                Suspension
# 123  2011-04-15 12:00:00 a.m.         W 0356930                    Issued
# 124  2012-12-19 12:00:00 a.m.         W 0402556                    Issued
# 125  2015-02-26 12:00:00 a.m.         W 0417219                 Abandoned
# 126  2012-03-08 12:00:00 a.m.         W 0128254                 Abandoned
# 127  2020-11-18 12:00:00 a.m.         W 0125048                 Abandoned
# 128  1996-01-31 12:00:00 a.m.         W 0029654                    Issued
# 129  2001-05-31 12:00:00 a.m.         W 0116982                   Amended
#
#     04.Surface Location   05.Bottom Location 06.Original BA Id  \
# 100      01-03-038-24W4  00/01-03-038-24W4/0              0HE9
# 101      07-10-040-13W4  00/01-03-040-13W4/0              A2J6
# 102      07-10-040-13W4  00/01-03-040-13W4/0              A7BT
# 103      07-10-040-13W4  00/01-03-040-13W4/0              A2J6
# 104      01-03-043-02W4  00/01-03-043-02W4/0              0039
# 105      16-03-050-04W5  00/01-03-050-04W5/0              A68R
# 106      01-03-050-06W4  00/01-03-050-06W4/0              0R46
# 107      01-03-050-07W4  00/01-03-050-07W4/0              0NX9
# 108      01-03-051-16W5  00/01-03-051-16W5/0              0XL9
# 109      01-03-052-04W4  00/01-03-052-04W4/0              0R46
# 110      01-03-053-14W4  00/01-03-053-14W4/0              A08E
# 111      16-34-052-23W5  00/01-03-053-23W5/2              0HE9
# 112      01-03-053-26W4  00/01-03-053-26W4/0              0BP8
# 113      08-03-055-03W4  00/01-03-055-03W4/0              0HE9
# 114      01-03-056-05W4  00/01-03-056-05W4/0              0HE9
# 115      01-03-056-05W4  00/01-03-056-05W4/0              0HE9
# 116      01-03-056-06W4  00/01-03-056-06W4/0              0HE9
# 117      01-03-056-06W4  00/01-03-056-06W4/0              0HE9
# 118      01-03-056-07W4  00/01-03-056-07W4/0              0HE9
# 119      16-34-055-15W4  00/01-03-056-15W4/0              0HE9
# 120      04-02-061-15W5  00/01-03-061-15W5/0              0MD6
# 121      01-03-061-26W4  00/01-03-061-26W4/0              A5YK
# 122      08-03-064-07W4  00/01-03-064-07W4/0              0K29
# 123      08-03-065-03W4  00/01-03-065-03W4/0              0007
# 124      09-03-069-13W6  00/01-03-069-13W6/0              A5LK
# 125      01-03-079-10W4  00/01-03-079-10W4/2              A327
# 126      01-03-089-03W5  00/01-03-089-03W5/0              0BP8
# 127      01-03-094-01W6  00/01-03-094-01W6/0              0YK4
# 128      01-03-109-08W6  00/01-03-109-08W6/0              0R46
# 129      14-35-109-07W6  00/01-03-110-07W6/2              0007
#
#                         07.Licensee at Reporting                  08.Type  \
# 100    Canadian Natural Resources Limited (0HE9)                Vent Flow
# 101                            Veren Inc. (A2J6)                Vent Flow
# 102                     Karve Energy Inc. (A7BT)                Vent Flow
# 103                            Veren Inc. (A2J6)                Vent Flow
# 104          Repsol Oil & Gas Canada Inc. (0039)                Vent Flow
# 105               Highvale Energy Limited (A68R)                Vent Flow
# 106          Husky Oil Operations Limited (0R46)  Vent Flow/Gas Migration
# 107                   Samson Canada, Ltd. (0NX9)                Vent Flow
# 108  ConocoPhillips Canada Operations ULC (0XL9)                Vent Flow
# 109          Husky Oil Operations Limited (0R46)            Gas Migration
# 110                     Omers Energy Inc. (A08E)                Vent Flow
# 111    Canadian Natural Resources Limited (0HE9)                Vent Flow
# 112                  Obsidian Energy Ltd. (0BP8)                Vent Flow
# 113    Canadian Natural Resources Limited (0HE9)                Vent Flow
# 114    Canadian Natural Resources Limited (0HE9)            Gas Migration
# 115    Canadian Natural Resources Limited (0HE9)            Gas Migration
# 116    Canadian Natural Resources Limited (0HE9)                Vent Flow
# 117    Canadian Natural Resources Limited (0HE9)            Gas Migration
# 118    Canadian Natural Resources Limited (0HE9)                Vent Flow
# 119    Canadian Natural Resources Limited (0HE9)                Vent Flow
# 120              Bonavista Petroleum Ltd. (0MD6)                Vent Flow
# 121                    Velvet Energy Ltd. (A5YK)                Vent Flow
# 122              Devon Canada Corporation (0K29)                Vent Flow
# 123        Imperial Oil Resources Limited (0007)            Gas Migration
# 124                   Pace Oil & Gas Ltd. (A5LK)                Vent Flow
# 125                   Equinor Canada Ltd. (A327)                Vent Flow
# 126                  Obsidian Energy Ltd. (0BP8)                Vent Flow
# 127                     Surge Energy Inc. (0YK4)                Vent Flow
# 128          Husky Oil Operations Limited (0R46)                Vent Flow
# 129        Imperial Oil Resources Limited (0007)                Vent Flow
#
#           09.Classification 10.Flow Substance  11.Flow Rate (m3/day)  \
# 100                 Serious               Gas                 983.00
# 101             Non Serious               Gas                   0.36
# 102             Non Serious               Gas                   0.14
# 103                 Serious               Gas                    NaN
# 104  Considered Non Serious               Gas                    NaN
# 105             Non Serious               Gas                   0.28
# 106                 Serious               Gas                    NaN
# 107             Non Serious     Not Converted                    NaN
# 108             Non Serious               Gas                  10.00
# 109             Non Serious               NaN                   0.00
# 110             Non Serious               Gas                    NaN
# 111             Non Serious               Gas                   2.27
# 112             Non Serious               Gas                  13.19
# 113             Non Serious               Gas                    NaN
# 114                 Serious               Gas                    NaN
# 115                 Serious               Gas                    NaN
# 116             Non Serious               Gas                   1.00
# 117                 Serious               Gas                    NaN
# 118             Non Serious               Gas                   0.60
# 119             Non Serious               Gas                    NaN
# 120             Non Serious               Gas                    NaN
# 121             Non Serious               Gas                   0.44
# 122             Non Serious               Gas                    NaN
# 123             Non Serious               Gas                    NaN
# 124                 Serious               Gas                 134.50
# 125  Considered Non Serious               Gas                    NaN
# 126             Non Serious               Gas                  75.52
# 127             Non Serious               Gas                  11.20
# 128             Non Serious               Gas                   0.00
# 129             Non Serious               Gas                    NaN
#
#      12.Stabilized Shut In Pressure (kPa)  13.Source Depth (mkb)  \
# 100                                 460.0                  600.0
# 101                                 319.0                    NaN
# 102                                   3.0                    NaN
# 103                                 319.0                    NaN
# 104                                 195.0                    NaN
# 105                                 160.0                    NaN
# 106                                   0.0                  295.0
# 107                                   NaN                    0.0
# 108                                   2.0                    NaN
# 109                                   0.0                    0.0
# 110                                 319.0                    NaN
# 111                                 150.0                    0.0
# 112                                1044.0                  190.2
# 113                                  28.0                    NaN
# 114                                   NaN                  246.0
# 115                                   NaN                    NaN
# 116                                  75.0                    0.0
# 117                                   NaN                  264.0
# 118                                1325.0                    NaN
# 119                                   0.0                    NaN
# 120                                2090.0                    NaN
# 121                                 404.0                    NaN
# 122                                  22.0                    NaN
# 123                                   NaN                    NaN
# 124                                 160.0                    NaN
# 125                                  23.0                    NaN
# 126                                 317.0                  635.0
# 127                                  39.0                  216.0
# 128                                   0.0                    0.0
# 129                                 240.0                    NaN
#
#      14.Ground Water Base (mkb)        15.Resolution Date  \
# 100                        0.00  1996-08-28 12:00:00 a.m.
# 101                      291.25  2015-06-02 12:00:00 a.m.
# 102                      404.87                       NaN
# 103                      291.25                       NaN
# 104                      190.00  2014-07-09 12:00:00 a.m.
# 105                      556.28                       NaN
# 106                      130.00  2011-11-20 12:00:00 a.m.
# 107                        0.00  2000-02-15 12:00:00 a.m.
# 108                      600.00                       NaN
# 109                        0.00  2002-07-06 12:00:00 a.m.
# 110                      215.70                       NaN
# 111                      600.00  2020-06-11 12:00:00 a.m.
# 112                      160.00  2024-03-25 12:00:00 a.m.
# 113                      158.00  2010-05-14 12:00:00 a.m.
# 114                       88.34  2011-08-05 12:00:00 a.m.
# 115                       88.34                       NaN
# 116                        0.00   2004-07-02 8:57:00 a.m.
# 117                       96.18  2013-10-29 12:00:00 a.m.
# 118                       36.29  2010-05-12 12:00:00 a.m.
# 119                      190.60  2015-04-07 12:00:00 a.m.
# 120                      290.00  2016-10-27 12:00:00 a.m.
# 121                      321.00                       NaN
# 122                      136.70  2018-09-28 12:00:00 a.m.
# 123                      205.84                       NaN
# 124                      782.31                       NaN
# 125                      303.60  2015-09-17 12:00:00 a.m.
# 126                      349.47  2012-06-26 12:00:00 a.m.
# 127                      570.79  2023-03-10 12:00:00 a.m.
# 128                        0.00  1996-01-31 12:00:00 a.m.
# 129                       69.40                       NaN
#
#     16.Reported Resolution
# 100       Problem Repaired
# 101               Died Out
# 102                    NaN
# 103     Entry Error-Ignore
# 104               Died Out
# 105                    NaN
# 106     Repaired - SCVF/GM
# 107       Problem Repaired
# 108                    NaN
# 109               Died Out
# 110                    NaN
# 111               Died Out
# 112     Repaired - SCVF/GM
# 113               Died Out
# 114     Repaired - SCVF/GM
# 115                    NaN
# 116    Monitor as Required
# 117     Repaired - SCVF/GM
# 118               Died Out
# 119               Died Out
# 120               Died Out
# 121                    NaN
# 122               Died Out
# 123                    NaN
# 124                    NaN
# 125               Died Out
# 126         Casing Failure
# 127     Repaired - SCVF/GM
# 128               Died Out
# 129                    NaN

# %%
df_clean[100:130]
# Out:
#     report_date  licence licence_status surface_location      bottom_location  \
# 100  1998-04-17  0142197      Abandoned   01-03-038-24W4  00/01-03-038-24W4/0
# 101  2014-10-24  0445591         Issued   07-10-040-13W4  00/01-03-040-13W4/0
# 102  2020-10-28  0445591         Issued   07-10-040-13W4  00/01-03-040-13W4/0
# 103  2014-09-12  0445591         Issued   07-10-040-13W4  00/01-03-040-13W4/0
# 104  2007-01-15  0362553      Abandoned   01-03-043-02W4  00/01-03-043-02W4/0
# 105  2023-08-23  0414819     Suspension   16-03-050-04W5  00/01-03-050-04W5/0
# 106  2011-08-26  0422035      Abandoned   01-03-050-06W4  00/01-03-050-06W4/0
# 107  2000-02-15  0118245   RecCertified   01-03-050-07W4  00/01-03-050-07W4/0
# 108  2012-09-18  0338838     Suspension   01-03-051-16W5  00/01-03-051-16W5/0
# 109  2002-11-07  0090097   RecCertified   01-03-052-04W4  00/01-03-052-04W4/0
# 110  2009-02-04  0402469         Issued   01-03-053-14W4  00/01-03-053-14W4/0
# 111  2018-05-31  0406866         Issued   16-34-052-23W5  00/01-03-053-23W5/2
# 112  2005-07-29  0003045   RecCertified   01-03-053-26W4  00/01-03-053-26W4/0
# 113  2008-04-01  0314450      Abandoned   08-03-055-03W4  00/01-03-055-03W4/0
# 114  2011-06-24  0093282      Abandoned   01-03-056-05W4  00/01-03-056-05W4/0
# 115  2020-08-26  0093282      Abandoned   01-03-056-05W4  00/01-03-056-05W4/0
# 116  1999-07-29  0092985      Abandoned   01-03-056-06W4  00/01-03-056-06W4/0
# 117  2000-05-05  0092985      Abandoned   01-03-056-06W4  00/01-03-056-06W4/0
# 118  2009-04-13  0409751   RecCertified   01-03-056-07W4  00/01-03-056-07W4/0
# 119  2000-07-27  0215817     Suspension   16-34-055-15W4  00/01-03-056-15W4/0
# 120  2007-04-11  0373571         Issued   04-02-061-15W5  00/01-03-061-15W5/0
# 121  2016-05-25  0344304     Suspension   01-03-061-26W4  00/01-03-061-26W4/0
# 122  2017-02-27  0480982     Suspension   08-03-064-07W4  00/01-03-064-07W4/0
# 123  2011-04-15  0356930         Issued   08-03-065-03W4  00/01-03-065-03W4/0
# 124  2012-12-19  0402556         Issued   09-03-069-13W6  00/01-03-069-13W6/0
# 125  2015-02-26  0417219      Abandoned   01-03-079-10W4  00/01-03-079-10W4/2
# 126  2012-03-08  0128254      Abandoned   01-03-089-03W5  00/01-03-089-03W5/0
# 127  2020-11-18  0125048      Abandoned   01-03-094-01W6  00/01-03-094-01W6/0
# 128  1996-01-31  0029654         Issued   01-03-109-08W6  00/01-03-109-08W6/0
# 129  2001-05-31  0116982        Amended   14-35-109-07W6  00/01-03-110-07W6/2
#
#     original_ba_id                        licensee_at_reporting  \
# 100           0HE9    Canadian Natural Resources Limited (0HE9)
# 101           A2J6                            Veren Inc. (A2J6)
# 102           A7BT                     Karve Energy Inc. (A7BT)
# 103           A2J6                            Veren Inc. (A2J6)
# 104           0039          Repsol Oil & Gas Canada Inc. (0039)
# 105           A68R               Highvale Energy Limited (A68R)
# 106           0R46          Husky Oil Operations Limited (0R46)
# 107           0NX9                   Samson Canada, Ltd. (0NX9)
# 108           0XL9  ConocoPhillips Canada Operations ULC (0XL9)
# 109           0R46          Husky Oil Operations Limited (0R46)
# 110           A08E                     Omers Energy Inc. (A08E)
# 111           0HE9    Canadian Natural Resources Limited (0HE9)
# 112           0BP8                  Obsidian Energy Ltd. (0BP8)
# 113           0HE9    Canadian Natural Resources Limited (0HE9)
# 114           0HE9    Canadian Natural Resources Limited (0HE9)
# 115           0HE9    Canadian Natural Resources Limited (0HE9)
# 116           0HE9    Canadian Natural Resources Limited (0HE9)
# 117           0HE9    Canadian Natural Resources Limited (0HE9)
# 118           0HE9    Canadian Natural Resources Limited (0HE9)
# 119           0HE9    Canadian Natural Resources Limited (0HE9)
# 120           0MD6              Bonavista Petroleum Ltd. (0MD6)
# 121           A5YK                    Velvet Energy Ltd. (A5YK)
# 122           0K29              Devon Canada Corporation (0K29)
# 123           0007        Imperial Oil Resources Limited (0007)
# 124           A5LK                   Pace Oil & Gas Ltd. (A5LK)
# 125           A327                   Equinor Canada Ltd. (A327)
# 126           0BP8                  Obsidian Energy Ltd. (0BP8)
# 127           0YK4                     Surge Energy Inc. (0YK4)
# 128           0R46          Husky Oil Operations Limited (0R46)
# 129           0007        Imperial Oil Resources Limited (0007)
#
#                   event_type          classification flow_substance  ...  \
# 100                Vent Flow                 Serious            Gas  ...
# 101                Vent Flow             Non Serious            Gas  ...
# 102                Vent Flow             Non Serious            Gas  ...
# 103                Vent Flow                 Serious            Gas  ...
# 104                Vent Flow  Considered Non Serious            Gas  ...
# 105                Vent Flow             Non Serious            Gas  ...
# 106  Vent Flow/Gas Migration                 Serious            Gas  ...
# 107                Vent Flow             Non Serious  Not Converted  ...
# 108                Vent Flow             Non Serious            Gas  ...
# 109            Gas Migration             Non Serious            NaN  ...
# 110                Vent Flow             Non Serious            Gas  ...
# 111                Vent Flow             Non Serious            Gas  ...
# 112                Vent Flow             Non Serious            Gas  ...
# 113                Vent Flow             Non Serious            Gas  ...
# 114            Gas Migration                 Serious            Gas  ...
# 115            Gas Migration                 Serious            Gas  ...
# 116                Vent Flow             Non Serious            Gas  ...
# 117            Gas Migration                 Serious            Gas  ...
# 118                Vent Flow             Non Serious            Gas  ...
# 119                Vent Flow             Non Serious            Gas  ...
# 120                Vent Flow             Non Serious            Gas  ...
# 121                Vent Flow             Non Serious            Gas  ...
# 122                Vent Flow             Non Serious            Gas  ...
# 123            Gas Migration             Non Serious            Gas  ...
# 124                Vent Flow                 Serious            Gas  ...
# 125                Vent Flow  Considered Non Serious            Gas  ...
# 126                Vent Flow             Non Serious            Gas  ...
# 127                Vent Flow             Non Serious            Gas  ...
# 128                Vent Flow             Non Serious            Gas  ...
# 129                Vent Flow             Non Serious            Gas  ...
#
#      sip_kpa  source_depth_mkb  gw_base_mkb     resolution_date  \
# 100    460.0             600.0         0.00 1996-08-28 00:00:00
# 101    319.0               NaN       291.25 2015-06-02 00:00:00
# 102      3.0               NaN       404.87                 NaT
# 103    319.0               NaN       291.25                 NaT
# 104    195.0               NaN       190.00 2014-07-09 00:00:00
# 105    160.0               NaN       556.28                 NaT
# 106      0.0             295.0       130.00 2011-11-20 00:00:00
# 107      NaN               0.0         0.00 2000-02-15 00:00:00
# 108      2.0               NaN       600.00                 NaT
# 109      0.0               0.0         0.00 2002-07-06 00:00:00
# 110    319.0               NaN       215.70                 NaT
# 111    150.0               0.0       600.00 2020-06-11 00:00:00
# 112   1044.0             190.2       160.00 2024-03-25 00:00:00
# 113     28.0               NaN       158.00 2010-05-14 00:00:00
# 114      NaN             246.0        88.34 2011-08-05 00:00:00
# 115      NaN               NaN        88.34                 NaT
# 116     75.0               0.0         0.00 2004-07-02 08:57:00
# 117      NaN             264.0        96.18 2013-10-29 00:00:00
# 118   1325.0               NaN        36.29 2010-05-12 00:00:00
# 119      0.0               NaN       190.60 2015-04-07 00:00:00
# 120   2090.0               NaN       290.00 2016-10-27 00:00:00
# 121    404.0               NaN       321.00                 NaT
# 122     22.0               NaN       136.70 2018-09-28 00:00:00
# 123      NaN               NaN       205.84                 NaT
# 124    160.0               NaN       782.31                 NaT
# 125     23.0               NaN       303.60 2015-09-17 00:00:00
# 126    317.0             635.0       349.47 2012-06-26 00:00:00
# 127     39.0             216.0       570.79 2023-03-10 00:00:00
# 128      0.0               0.0         0.00 1996-01-31 00:00:00
# 129    240.0               NaN        69.40                 NaT
#
#      reported_resolution licence_raw delta_gw  duration_days  is_serious  \
# 100     Problem Repaired   W 0142197  -600.00         -597.0           1
# 101             Died Out   W 0445591      NaN          221.0           0
# 102                  NaN   W 0445591      NaN            NaN           0
# 103   Entry Error-Ignore   W 0445591      NaN            NaN           1
# 104             Died Out   W 0362553      NaN         2732.0           0
# 105                  NaN   W 0414819      NaN            NaN           0
# 106   Repaired - SCVF/GM   W 0422035  -165.00           86.0           1
# 107     Problem Repaired   W 0118245     0.00            0.0           0
# 108                  NaN   W 0338838      NaN            NaN           0
# 109             Died Out   W 0090097     0.00         -124.0           0
# 110                  NaN   W 0402469      NaN            NaN           0
# 111             Died Out   W 0406866   600.00          742.0           0
# 112   Repaired - SCVF/GM   W 0003045   -30.20         6814.0           0
# 113             Died Out   W 0314450      NaN          773.0           0
# 114   Repaired - SCVF/GM   W 0093282  -157.66           42.0           1
# 115                  NaN   W 0093282      NaN            NaN           1
# 116  Monitor as Required   W 0092985     0.00         1800.0           0
# 117   Repaired - SCVF/GM   W 0092985  -167.82         4925.0           1
# 118             Died Out   W 0409751      NaN          394.0           0
# 119             Died Out   W 0215817      NaN         5367.0           0
# 120             Died Out   W 0373571      NaN         3487.0           0
# 121                  NaN   W 0344304      NaN            NaN           0
# 122             Died Out   W 0480982      NaN          578.0           0
# 123                  NaN   W 0356930      NaN            NaN           0
# 124                  NaN   W 0402556      NaN            NaN           1
# 125             Died Out   W 0417219      NaN          203.0           0
# 126       Casing Failure   W 0128254  -285.53          110.0           0
# 127   Repaired - SCVF/GM   W 0125048   354.79          842.0           0
# 128             Died Out   W 0029654     0.00            0.0           0
# 129                  NaN   W 0116982      NaN            NaN           0
#
#      report_year
# 100         1998
# 101         2014
# 102         2020
# 103         2014
# 104         2007
# 105         2023
# 106         2011
# 107         2000
# 108         2012
# 109         2002
# 110         2009
# 111         2018
# 112         2005
# 113         2008
# 114         2011
# 115         2020
# 116         1999
# 117         2000
# 118         2009
# 119         2000
# 120         2007
# 121         2016
# 122         2017
# 123         2011
# 124         2012
# 125         2015
# 126         2012
# 127         2020
# 128         1996
# 129         2001
#
# [30 rows x 21 columns]

# %%
# Rows where 'licence' appears more than once
df_clean[df_clean["licence"].duplicated(keep=False)]
# Out:
#       report_date  licence licence_status surface_location  \
# 14     2000-12-01  0206090         Issued   01-01-013-16W4
# 15     1999-12-06  0206090         Issued   01-01-013-16W4
# 19     1998-06-02  0099731         Issued   01-01-038-03W5
# 20     2005-08-30  0099731         Issued   01-01-038-03W5
# 35     2020-09-18  0010134     Suspension   01-01-069-22W5
# ...           ...      ...            ...              ...
# 39610  2007-02-07  0184162     Suspension   13-05-061-11W5
# 39623  2024-06-25  0354769        Amended   07-32-075-06W4
# 39624  2014-12-29  0354769        Amended   07-32-075-06W4
# 39627  2014-11-19  0464573        Amended   13-20-062-07W4
# 39628  2015-01-23  0464573        Amended   13-20-062-07W4
#
#            bottom_location original_ba_id  \
# 14     00/01-01-013-16W4/0           0031
# 15     00/01-01-013-16W4/0           0HE9
# 19     00/01-01-038-03W5/0           0Z0H
# 20     00/01-01-038-03W5/0           0Z0H
# 35     00/01-01-069-22W5/0           0HE9
# ...                    ...            ...
# 39610  W0/13-05-061-11W5/2           0BP8
# 39623  W2/04-04-076-06W4/0           0HE9
# 39624  W2/04-04-076-06W4/0           0K29
# 39627  W2/05-20-062-07W4/0           0HE9
# 39628  W2/05-20-062-07W4/0           0HE9
#
#                            licensee_at_reporting     event_type  \
# 14            Anadarko Canada Corporation (0031)      Vent Flow
# 15     Canadian Natural Resources Limited (0HE9)  Gas Migration
# 19               Harvest Operations Corp. (0Z0H)      Vent Flow
# 20               Harvest Operations Corp. (0Z0H)      Vent Flow
# 35     Canadian Natural Resources Limited (0HE9)      Vent Flow
# ...                                          ...            ...
# 39610                Obsidian Energy Ltd. (0BP8)      Vent Flow
# 39623  Canadian Natural Resources Limited (0HE9)      Vent Flow
# 39624            Devon Canada Corporation (0K29)  Gas Migration
# 39627  Canadian Natural Resources Limited (0HE9)      Vent Flow
# 39628  Canadian Natural Resources Limited (0HE9)      Vent Flow
#
#                classification flow_substance  ...  sip_kpa  source_depth_mkb  \
# 14                Non Serious            Gas  ...      7.0               0.0
# 15                Non Serious            NaN  ...      0.0               0.0
# 19                Non Serious            Gas  ...    297.0               0.0
# 20                Non Serious            Gas  ...    889.0               NaN
# 35     Considered Non Serious            Gas  ...      6.0               0.0
# ...                       ...            ...  ...      ...               ...
# 39610             Non Serious            Gas  ...    128.0               NaN
# 39623             Non Serious            Gas  ...      0.0               NaN
# 39624             Non Serious            Gas  ...      NaN               NaN
# 39627             Non Serious            Gas  ...   1032.0               NaN
# 39628             Non Serious            Gas  ...      1.0               NaN
#
#        gw_base_mkb     resolution_date  reported_resolution licence_raw  \
# 14            0.00 2000-12-01 00:00:00             Died Out   W 0206090
# 15            0.00 2007-01-03 16:33:00  Monitor as Required   W 0206090
# 19            0.00 2006-07-10 16:31:00  Monitor as Required   W 0099731
# 20          361.00                 NaT                  NaN   W 0099731
# 35          481.70 2021-08-30 00:00:00             Died Out   W 0010134
# ...            ...                 ...                  ...         ...
# 39610       600.00                 NaT                  NaN   W 0184162
# 39623       281.00                 NaT                  NaN   W 0354769
# 39624       281.00 2024-06-25 00:00:00             Died Out   W 0354769
# 39627        47.16 2014-11-14 00:00:00   Entry Error-Ignore   W 0464573
# 39628        47.16                 NaT                  NaN   W 0464573
#
#       delta_gw  duration_days  is_serious  report_year
# 14         0.0            0.0           0         2000
# 15         0.0         2585.0           0         1999
# 19         0.0         2960.0           0         1998
# 20         NaN            NaN           0         2005
# 35       481.7          346.0           0         2020
# ...        ...            ...         ...          ...
# 39610      NaN            NaN           0         2007
# 39623      NaN            NaN           0         2024
# 39624      NaN         3466.0           0         2014
# 39627      NaN           -5.0           0         2014
# 39628      NaN            NaN           0         2015
#
# [12245 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39638 entries, 0 to 39637
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   01.Report Date                        39638 non-null  object
#  1   02.Licence Number                     39638 non-null  object
#  2   03.Current Licence Status             39638 non-null  object
#  3   04.Surface Location                   39638 non-null  object
#  4   05.Bottom Location                    39627 non-null  object
#  5   06.Original BA Id                     39638 non-null  object
#  6   07.Licensee at Reporting              39638 non-null  object
#  7   08.Type                               39635 non-null  object
#  8   09.Classification                     39635 non-null  object
#  9   10.Flow Substance                     38666 non-null  object
#  10  11.Flow Rate (m3/day)                 22767 non-null  float64
#  11  12.Stabilized Shut In Pressure (kPa)  36040 non-null  float64
#  12  13.Source Depth (mkb)                 16445 non-null  float64
#  13  14.Ground Water Base (mkb)            39533 non-null  float64
#  14  15.Resolution Date                    28210 non-null  object
#  15  16.Reported Resolution                28458 non-null  object
# dtypes: float64(4), object(12)
# memory usage: 4.8+ MB

# %%
import matplotlib.pyplot as plt

# Scatter plot: flow_rate vs another variable (e.g., source_depth)
plt.figure(figsize=(8,6))
scatter = plt.scatter(
    df_clean["flow_rate_m3d"],
    df_clean["source_depth_mkb"],   # replace with the column you want on y-axis
    c=df_clean["is_serious"],      # color by "serious" column
    cmap="bwr",                 # blue/red colormap
    alpha=0.7
)

plt.colorbar(scatter, label="Serious")
plt.xlabel("Flow Rate")
plt.ylabel("Source Depth")
plt.title("Flow Rate vs Source Depth colored by Serious")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
#sns.boxplot(data=df_clean, x="is_serious", y="flow_rate_m3d")
sns.stripplot(data=df_clean, x="is_serious", y="flow_rate_m3d",
              color="black", size=3, alpha=0.5)  # optional, adds scatter points
plt.xlabel("Serious (0 = No, 1 = Yes)")
plt.ylabel("Flow Rate")
plt.title("Flow Rate vs Seriousness")
plt.show()

plt.figure(figsize=(7,5))
sns.histplot(data=df_clean, x="flow_rate_m3d", hue="is_serious",
             element="step", common_norm=False)
plt.title("Distribution of Flow Rate by Seriousness")
plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(data=df_clean, x="flow_substance", y="flow_rate_m3d", hue="is_serious", palette="Set2")

plt.xticks(rotation=45)
plt.title("Flow Rate by Flow Type and Seriousness")
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(data=df_clean, x="reported_resolution", y="flow_rate_m3d")

plt.xticks(rotation=45)
plt.title("Flow Rate by Flow Type and Seriousness")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_clean[df_clean["is_serious"] == 1], x="flow_substance", y="flow_rate_m3d")

plt.xticks(rotation=45)
plt.ylabel("Flow Rate")
plt.xlabel("Flow Substance")
plt.title("Flow Rate by Flow Type for Serious Leakages")
plt.show()

# %%
df_clean.columns
# Out:
# Index(['report_date', 'licence', 'licence_status', 'surface_location',
#        'bottom_location', 'original_ba_id', 'licensee_at_reporting',
#        'event_type', 'classification', 'flow_substance', 'flow_rate_m3d',
#        'sip_kpa', 'source_depth_mkb', 'gw_base_mkb', 'resolution_date',
#        'reported_resolution', 'licence_raw', 'delta_gw', 'duration_days',
#        'is_serious', 'report_year'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.countplot(
    data=df_clean[(df_clean["is_serious"] == 1) & (df_clean["flow_substance"] == "Gas")],
    x="reported_resolution",
    order=df_clean["reported_resolution"].value_counts().index,
    palette="Set2"
)

plt.xticks(rotation=90)
plt.ylabel("Count")
plt.xlabel("Resolution")
plt.title("Resolutions of Serious Gas Leakages")
plt.show()
# Out:
# /tmp/ipykernel_5996/497674863.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_clean[df_clean["is_serious"] == 0], x="flow_substance", y="flow_rate_m3d")

plt.xticks(rotation=45)
plt.ylabel("Flow Rate")
plt.xlabel("Flow Substance")
plt.title("Flow Rate by Flow Type for non-Serious Leakages")
plt.show()

# %%
df_clean.columns
# Out:
# Index(['report_date', 'licence', 'licence_status', 'surface_location',
#        'bottom_location', 'original_ba_id', 'licensee_at_reporting',
#        'event_type', 'classification', 'flow_substance', 'flow_rate_m3d',
#        'sip_kpa', 'source_depth_mkb', 'gw_base_mkb', 'resolution_date',
#        'reported_resolution', 'licence_raw', 'delta_gw', 'duration_days',
#        'is_serious', 'report_year'],
#       dtype='object')
